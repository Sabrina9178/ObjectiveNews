# %%
import datetime
from selenium.webdriver.edge.options import Options
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

def find_PNN_news(n_hours_ago):

    options = Options()
    driver = webdriver.Edge(options=options)

    # 新聞網站 URL
    url = "https://news.pts.org.tw/dailynews"
    driver.get(url)
    

    # 初始化一個空字典來存放時間
    news = {}

    index = 1

    # 用於存儲已找到的新聞標題
    finded_news_titles = set()

    # 持續滾動頁面,直到找不到符合時間範圍的新聞為止
    while True:

        # 找到所有新聞項目
        news_items = driver.find_elements(By.CSS_SELECTOR, "li.d-flex")

        # 如果沒有新的新聞項目,退出循環
        if not news_items:
            break
        
        # 標記本次循環是否找到了符合時間範圍的新聞
        found_new_news = False

        # 遍歷每個新聞項目
        for item in news_items:
            
            # 獲取標題
            title_element = item.find_element(By.CSS_SELECTOR, "h2")
            news_title = title_element.get_attribute('title') if title_element else ""
            
            # 如果標題已經被處理過,跳過
            if news_title in finded_news_titles:
                continue
            
            # 獲取時間
            time_element = item.find_element(By.CSS_SELECTOR, "time")
            news_time_str = time_element.text if time_element else ""
            # 判斷時間字串的格式是否與當前時間格式一致
            try:
                news_time = datetime.datetime.strptime(news_time_str, "%Y-%m-%d %H:%M")
            except ValueError:
                news_time = datetime.datetime.strptime(news_time_str, "%m/%d %H:%M")
                news_time = news_time.replace(year=now.year)
                
            # 如果新聞時間在n小時範圍內
            if n_hours_ago <= news_time:
                found_new_news = True
                finded_news_titles.add(news_title)  # 將標題加入已處理集合

                link_element = item.find_element(By.CSS_SELECTOR, "h2 > a")
                news_link = link_element.get_attribute('href') if link_element else ""

                category_element = item.find_element(By.CSS_SELECTOR, "div.news-info > a")
                news_category = category_element.text if category_element else ""

                
                # print(f"標題: {news_title}")
                # print(f"連結: {news_link}")
                # print(f"時間: {news_time_str}")
                # print(f"分類: {news_category}")
                # print("-------------------")

                news[index] = [news_title, news_link, news_time, news_category]
                index += 1

                driver.execute_script("window.scrollBy(0, 1000);")
                time.sleep(1)  # 等待頁面響應
                
        # 如果本次循環中沒有找到符合時間範圍的新聞,就退出
        if not found_new_news:
            break
        else:
            target_element = driver.find_element(By.CSS_SELECTOR, 'a[class="cursor-default"]')
            next_element = target_element.find_element(By.XPATH, './following::li[1]/a')
            link_href = next_element.get_attribute("href")
            driver.get(link_href)


    # 訪問每個新聞詳情頁,爬取內文
    for index in news:

        driver.get(news[index][1])
        content_elements = driver.find_elements(By.CSS_SELECTOR, "p")
        news_content = "\n".join([p.text for p in content_elements])

        news[index].append(news_content)
        # print(f"標題: {news[index][0]}")
        # print(f"內文: {news[index][-1]}")

    return news

    #關閉瀏覽器
    # driver.quit()

# %%
# find_PNN_news(6)
# Out:
# Current date and time: 2024-03-16 23:08:09.651340
# Current time: 23:08:09.651340
# 6 hours ago:2024-03-16 17:08:09.651340
# 標題: 音樂會追思遭割頸國中生 受害家屬籲修法讓家長負刑責
# 連結: https://news.pts.org.tw/article/685709
# 時間: 2024-03-16 18:56
# 分類: 社福人權
# -------------------
# 標題: 屏東車城公共女湯曾遭男誤闖 公所加強巡視並張貼公告
# 連結: https://news.pts.org.tw/article/685708
# 時間: 2024-03-16 18:53
# 分類: 地方
# -------------------
# 標題: 以哈戰爭／2百噸物資船運抵加薩 盼海上救援公路從此開通
# 連結: https://news.pts.org.tw/article/685707
# 時間: 2024-03-16 18:47
# 分類: 全球
# -------------------
# 標題: 中職熱身賽大巨蛋開打 龍象戰逾1.9萬人觀賽
# 連結: https://news.pts.org.tw/article/685706
# 時間: 2024-03-16 18:41
# 分類: 文教科技
# -------------------
# 標題: 泰國1至3月空污嚴重 清邁一度達非常不健康等級
# 連結: https://news.pts.org.tw/article/685705
# 時間: 2024-03-16 18:37
# 分類: 全球
# -------------------
# 標題: 新生代總鋪師林祺銘掌鼎 內門宋江大宴席開50桌
# 連結: https://news.pts.org.tw/article/685704
# 時間: 2024-03-16 18:32
# 分類: 地方
# -------------------
# no
# 標題: 音樂會追思遭割頸國中生 受害家屬籲修法讓家長負刑責
# 內文: 向去（2023）年底、在新北校園割頸案中喪生的楊姓學生，獻上一朵朵蒲公英悼念，民團「孩想陪你長大」16日舉行追思音樂會，不少父母帶著小孩一起參加。
# 楊爸爸、楊媽媽也親自出席，談起懂事的兒子依然滿是思念，更忍不住落淚。
# 楊爸爸說：「他真的都很聽我的話，我只要跟他講什麼，他就會去做，可是他這樣子，我真的沒辦法接受，每天還是會想著他。」
# 對於兩名加害學生受《少年事件處理法》保護，楊爸爸、楊媽媽無法接受，呼籲《少事法》應修法，讓未成年不得「塗銷前科」、不得「減輕其刑」，家長也需負連帶刑責。
# 楊爸爸表示，「家長應該也要負一些責任了吧，這樣子才是算公平的。」楊媽媽也指出，「我覺得《少事法》不應該以年齡來做一個保護的原則。」
# 司法院回應，就少年前案紀錄塗銷制度部分，已研議朝向「增設塗銷條件」等方向進行修法。
# 然而校園安全部分也需相關單位檢討，畢竟割頸案才發生未滿3個月，北市某國中又出現學生持刀追逐的衝突。
# 當事學校輔導主任表示，「其中有位學生他的情緒突然失控，所以就有一些不當的行為產生，拿美工刀出來是第一次，之前他也有所謂的情緒失控的情況，本來就是校內的高關懷學生。」
# 事發在14日的午休時間，導師開會不在教室時，兩名學生發生爭執，A生突然拿出兩把美工刀、作勢揮舞攻擊B生，一旁勸架的同學還被揮拳擊中。所幸隔壁班導師聽到吵鬧聲後趕緊介入，奪走美工刀才化解，衝突過程不到2分鐘。但讓學生們都嚇壞。
# 目前校方已讓輔導老師入班，並完成校安通報，也安排A生暫不回原班上課。而北市教育局表示，後續將協助學校提供相關情緒輔導管理資源。
# 標題: 屏東車城公共女湯曾遭男誤闖 公所加強巡視並張貼公告
# 內文: 這間位在百年泉源旁邊的四重溪溫泉浴室已啟用30幾年，近來男女湯屋被貼上公告，寫著有男性進入女湯區，造成民眾恐慌，也強調再有類似情況會報警處理。
# 消息一出引發討論，但有當地居民懷疑是否為誤闖。
# 當地居民認為，「眼睛視力比較模糊，不小心誤闖就會立刻喊他，這邊都有人在。」
# 有的泡湯民眾則說：「進去那個男、女湯門牌寫那麼清楚，如果這個樣子哪有可能會搞錯。」、「因為那還隔了一道門在，也沒有甚麼危險性。」
# 居民說誤闖的情況的確有過，但在門口就會被制止。
# 公所表示確實有人闖入女湯屋，但是發生於去年11月，當時1名六旬老翁，疑似視力不好誤闖，所幸當下沒有人在裡頭。
# 屏東車城鄉長陳政雄表示，「60至70歲，因為可能說有點失智，誤闖四重溪公共浴室的女湯，那一進去馬上被民眾發現，馬上制止、請他馬上出來。」
# 管理員也說：「女湯還要彎一個彎才看到浴池，男湯屋就比較開放。」
# 公所表示，正對公共浴室門口有監視器24小時監控，張貼公告是為了避免其他有心人士擅闖，後續也已加強管理員巡訪密度，避免再次發生。
# 標題: 以哈戰爭／2百噸物資船運抵加薩 盼海上救援公路從此開通
# 內文: 一家四口搭著驢車，準備從加薩北部往南方逃難，父親滿臉無奈，因為北方食物短缺，得設法找活路；母親抱著雙眼無神的孩子，拿著奶瓶心痛表示，孩子就算肚子餓了也只能餵他喝水。
# 加薩難民迪布太太說：「小孩子到底做了什麼？要這樣挨餓。」另一位難民迪布也說：「飢餓快把我們殺死了。」
# 以哈衝突超過5個月，首艘抵達加薩的緊急救援船也許帶來一絲希望。搭載糧食的「展臂號」，在當地時間15日白天映入眼簾，居民在岸上引頸期盼，有父親說孩子現在只有野生植物可吃，好希望拿到麵粉做麵包。
# 加薩難民指出，「我希望拿東西給孩子吃，我希望他們能活下去，不要被餓死。」
# 加薩缺乏基礎設施，雖然緊急蓋了臨時碼頭，大船仍無法靠岸，必須靠接駁船，再以起重機卸載貨物。
# 這艘由慈善機構「世界中央廚房」安排的救援船，12日從賽普勒斯啟航，裝有麵粉、米、肉罐頭、椰棗等共200噸糧食，該機構希望能就此開通海上救援公路。
# 世界中央廚房首席通訊官琳達羅斯表示，「這相當於近50萬份餐食，雖然我們知道加薩的每個人都需要更多的食物，但這對我們來說來說只是開始，我們希望再次開通這條海上高速公路。」
# 以哈衝突物資難以大量運入，加薩地區230萬人口，聯合國警告約四分之一處於飢荒邊緣。陸路救援障礙重重，首艘糧食救援船從海上抵達，帶給居民一線希望，而第二批物資也已經完成裝載、等待儘快送達。
# 標題: 中職熱身賽大巨蛋開打 龍象戰逾1.9萬人觀賽
# 內文: 球迷魚貫入場、迫不及待，中職熱身賽首次在台北大巨蛋進行，每走幾步路，就有大型立牌或工作人員手舉牌，提醒該從哪個方向、哪個入口進去。
# 有球迷說：「進來好像還是只有開一個入口吧，所以還是會比較擠一點，但是進來之後都還好。」、「交流賽遇到的問題，這次看他們都已經有安排過了，就是包含上二樓那個樓梯那邊，都是一開始就已經預設好。」
# 熱身賽開放內野2萬席，不比3月初讀賣巨人首場交流賽的3萬7千890人那麼多，但球迷感受，進場動線清楚不少、上下樓層不再只有手扶梯，優化不少。
# 中職副秘書長蔡克斯表示，「透過在熱身賽這次優化之後的結果，然後接下來的例行賽或者是更大型的賽事，聯盟會持續的進步。」
# 大巨蛋效應持續，就連味全龍42歲球星林智勝都說，自己到今天才首次踏進大巨蛋，感覺太棒了。
# 味全龍內野手林智勝說：「之前都是去別的國家，然後都會羡慕，今天又站在這裡會覺得蠻有榮幸的，就是可以在卸下球員以前還可以站在裡面打球，我覺得蠻幸福的。」
# 能來大巨蛋比賽，林智勝覺得開心，和他同年齡的兄弟球星周思齊，確定季後引退，現在是打一場少一場，感觸又有點複雜。
# 中信兄弟外野手周思齊表示，「因為打一場少一場，心情不好啊，要離開了哪有好？所以希望大家來球場聚聚。」
# 知名樂團表演，熱身賽增加假日女孩應援，中職不諱言，就是要把握大巨蛋熱度，讓新的球迷願意進來，從非本質球迷，進而成為本質球迷。
# 標題: 泰國1至3月空污嚴重 清邁一度達非常不健康等級
# 內文: 市區一片霧濛濛，觀景台上拍照的遊客，什麼都看不清楚。位於泰國北部的第二大城清邁，是受到國際旅客歡迎的觀光勝地，但這週15日，整座城市都被有毒空氣籠罩，危害居民健康，連返回家鄉清邁祭祖的前總理戴克辛，也只能戴上口罩跟民眾互動。
# 清邁單車騎士吉拉梅薩說：「每年都有空污問題，這種霧霾還算小的，更糟的嚴重10倍以上都有。」
# 每年上半年，泰國許多城市常常處在嚴重霧霾中，尤其是北部地區受到森林火災和農民焚燒稻梗影響，空污問題難以解決，而週五（15日）清邁的空氣品質指標更一度突破200，屬於非常不健康等級。
# 法新社報導，如今因空污罹患肺癌、支氣管炎等疾病的泰國人愈來愈多，今年截至3月初約有160萬人尋求治療，比去年同期增加了30萬人。
# 清邁大學生布特龐指出，「我沒有戴口罩的那一天就會暴露在污染中，回家後手臂過敏出現皮疹，還因為鼻塞難以呼吸。」
# 泰國總理賽塔去年上任後，就把解決空污問題列入重點項目，今年1月國會也一讀通過《乾淨空氣法》草案。
# 不過有些專家不看好這項法案，德國之聲指出，相較首都曼谷地區，以交通和工業廢氣為主要污染源，農村地區得禁止焚燒稻梗，但這麼做恐怕會使農業生產成本提高，而泰國法律也不可能要求同樣焚燒農業廢棄物的鄰國遵守規定，因此難防霧霾跨越國界。
# 標題: 新生代總鋪師林祺銘掌鼎 內門宋江大宴席開50桌
# 內文: 滷得香噴噴的虎皮封肉，還有鮮烤龍虎石斑魚，高雄內門一年一度的宋江大宴，16日正式展開，每桌8800元的手路菜，還包含魚翅羹、佛跳牆等十道經典料理，吸引50桌民眾前來體驗。
# 民眾說：「就是比較古早味，魚翅羹啊，就古早味的東西，爸爸媽媽也喜歡。」
# 今年內門宋江陣，從9日到24日在紫竹寺熱鬧展開，有精彩的全國創意宋江陣頭大賽、獲文化部指定為國家重要民俗的「羅漢門迎佛祖遶境」文武藝陣大匯演。
# 外界同樣關注的「宋江大宴」，則由在地新生代總鋪師林祺銘掌鼎，在觀亭國小旁的萃文書院開桌。
# 掌鼎總舖師林祺銘表示，「體現我們內門傳統的辦桌，二路菜魚翅羹、虎皮封肉，還有南部最特別的霸氣桶裝冰淇淋，然後搭配我們中南部養殖的龍虎石斑魚下去做烤的。」
# 布袋戲大車拼，80個戲棚一字排開，彰化縣芬園鄉縣庄村福德宮宮慶大典酬神公演，吸引許多民眾來觀賞。
# 民眾說，「小孩子喜歡看布袋戲啊，帶他來感受一下。」
# 廟方表示，每年酬神公演一天一戲棚，往往要持續60多天擾鄰，因此前年開始集中公演，卻意外引發熱潮，從前年66團、去年68團、到今年原定接受70團，最後有80團報名，年年刷新紀錄。
# 縣庄福德宮主委郭哲榮表示，「因為1天天做，連續做60幾天，影響到鄰居的安寧，太吵，所以我就改成一次性做這樣。」
# 史詩級畫面，要讓土地公和信眾看得過癮，也凝聚了地方虔誠的宗教信仰。

# %%
# import datetime
# from selenium.webdriver.edge.options import Options
# from selenium.common.exceptions import NoSuchElementException
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# import time
# import csv
# options = Options()
# driver = webdriver.Edge(options=options)
# url = "https://news.pts.org.tw/dailynews?page=2"
# driver.get(url)

# target_element = driver.find_element(By.CSS_SELECTOR, 'a[class="cursor-default"]')
# next_element = target_element.find_element(By.XPATH, './following::li[1]/a')
# link_href = next_element.get_attribute("href")
# driver.get(link_href)
